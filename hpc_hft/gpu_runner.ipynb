# %%
# !nvidia-smi
# Out:
# Fri Jun 12 14:02:43 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !nvidia-smi
# Out:
# Sat Jun 20 11:47:09 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git pull origin main
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !pwd
# Out:
# /content

# %%
# !git clone https://github.com/Abhishek-Chintada/code_files/hpc_hft
# Out:
# Cloning into 'hpc_hft'...
# remote: Not Found
# fatal: repository 'https://github.com/Abhishek-Chintada/code_files/hpc_hft/' not found

# %%
# !git clone https://github.com/Abhishek-Chintada/code_files/tree/main/hpc_hft
# Out:
# Cloning into 'hpc_hft'...
# fatal: repository 'https://github.com/Abhishek-Chintada/code_files/tree/main/hpc_hft/' not found
