# %%
# !nvidia-smi
# Out:
# Fri Jun 12 14:02:43 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !nvidia-smi
# Out:
# Sat Jun 20 11:47:09 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git pull origin main
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !pwd
# Out:
# /content

# %%
# !git clone https://github.com/Abhishek-Chintada/code_files/hpc_hft
# Out:
# Cloning into 'hpc_hft'...
# remote: Not Found
# fatal: repository 'https://github.com/Abhishek-Chintada/code_files/hpc_hft/' not found

# %%
# !git clone https://github.com/Abhishek-Chintada/code_files/tree/main/hpc_hft
# Out:
# Cloning into 'hpc_hft'...
# fatal: repository 'https://github.com/Abhishek-Chintada/code_files/tree/main/hpc_hft/' not found

# %%
# !nvidia-smi
# Out:
# Sat Jun 20 12:18:20 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git clone https://github.com/Abhishek-Chintada/pieceOfShit
# Out:
# Cloning into 'pieceOfShit'...
# remote: Enumerating objects: 1861, done.
# remote: Counting objects: 100% (1861/1861), done.
# remote: Compressing objects: 100% (1052/1052), done.
# remote: Total 1861 (delta 795), reused 1861 (delta 795), pack-reused 0 (from 0)
# Receiving objects: 100% (1861/1861), 3.99 MiB | 8.72 MiB/s, done.
# Resolving deltas: 100% (795/795), done.

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# pieceOfShit  sample_data

# %%
# !cd pieceOfShit/hpc_hft/

# %%
# !ls
# Out:
# pieceOfShit  sample_data

# %%
# !cd pieceOfShit

# %%
# !ls
# Out:
# pieceOfShit  sample_data

# %%
# !ls
# !nvcc hello_cuda.cu -o hello_cuda
# !./hello_cuda
# Out:
# pieceOfShit  sample_data
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# cc1plus: fatal error: hello_cuda.cu: No such file or directory
# compilation terminated.
# /bin/bash: line 1: ./hello_cuda: No such file or directory

# %%
# !ls
# Out:
# pieceOfShit  sample_data

# %%
# %cd pieceOfShit
# Out:
# /content/pieceOfShit

# %%
# !ls
# Out:
# hpc_hft

# %%
# %cd hpc_hft
# Out:
# /content/pieceOfShit/hpc_hft

# %%
# !ls
# Out:
# cuda_includes  gpu_runner.ipynb  hello_cuda  hello_cuda.cu

# %%
./hello_cuda
# Out:
#   File "/tmp/ipykernel_12072/2105002925.py", line 1
#     ./hello_cuda
#     ^
# SyntaxError: invalid syntax

# %%
# !./hello_cuda
# Out:
# This is the CPU talking to you now! Handing over the load to the GPU...
# Hello from the GPU! This is thread 0 from the block 0
# Hello from the GPU! This is thread 1 from the block 0
# Hello from the GPU! This is thread 2 from the block 0
# Hello from the GPU! This is thread 3 from the block 0
# Hello from the GPU! This is thread 4 from the block 0
# The GPU workload is complete. Basically Shit is done.
# <CPU in control now>

# %%
# !nvidia-smi
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# !nvidia-smi
# Out:
# Tue Jun 23 11:30:50 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git pull https://github.com/Abhishek-Chintada/pieceOfShit.git
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git clone https://github.com/Abhishek-Chintada/pieceOfShit.git
# Out:
# Cloning into 'pieceOfShit'...
# remote: Enumerating objects: 1885, done.
# remote: Counting objects: 100% (1885/1885), done.
# remote: Compressing objects: 100% (1067/1067), done.
# remote: Total 1885 (delta 808), reused 1880 (delta 803), pack-reused 0 (from 0)
# Receiving objects: 100% (1885/1885), 4.00 MiB | 15.93 MiB/s, done.
# Resolving deltas: 100% (808/808), done.

# %%
# !ls
# Out:
# pieceOfShit  sample_data

# %%
# %cd pieceOfShit/hpc_hft/
# Out:
# /content/pieceOfShit/hpc_hft

# %%
# !ls
# Out:
# cuda_includes  gpu_runner.ipynb  hello_cuda.cu

# %%
# %cd
# Out:
# /root

# %%
# !ls

# %%
# !pwd
# Out:
# /root

# %%
# !ls

# %%
# !reboot
# Out:
# System has not been booted with systemd as init system (PID 1). Can't operate.
# Failed to connect to bus: Host is down
# Failed to talk to init daemon.

# %%
# !ls

# %%
# !cd

# %%
# !ls

# %%
# %cd /content
# Out:
# /content

# %%
# !ls
# Out:
# pieceOfShit  sample_data

# %%
# !rm -rf pieceOfShit

# %%
# !ls
# Out:
# sample_data

# %%
# !git clone https://github.com/Abhishek-Chintada/pieceOfShit
# Out:
# Cloning into 'pieceOfShit'...
# remote: Enumerating objects: 1889, done.
# remote: Counting objects: 100% (1889/1889), done.
# remote: Compressing objects: 100% (1070/1070), done.
# remote: Total 1889 (delta 809), reused 1884 (delta 804), pack-reused 0 (from 0)
# Receiving objects: 100% (1889/1889), 4.00 MiB | 11.44 MiB/s, done.
# Resolving deltas: 100% (809/809), done.

# %%
# %cd pieceOfShit/hpc_hft/
# Out:
# /content/pieceOfShit/hpc_hft

# %%
# !ls
# Out:
# cuda_includes  executable  gpu_runner.ipynb  hello_cuda.cu  mat_mult.cu

# %%
# !nvcc mat_mult.cu -o mat_mult
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# mat_mult.cu(45): error: identifier "MatrixMultiplicationKernel" is undefined
#       MatrixMultiplicationKernel<<<dimGrid, dimBlock>>>(arr1d, arr2d, prod, size);
#       ^
#
# 1 error detected in the compilation of "mat_mult.cu".

# %%
# !git pull
# Out:
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 9 (delta 7), reused 6 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (9/9), 1.53 KiB | 523.00 KiB/s, done.
# From https://github.com/Abhishek-Chintada/pieceOfShit
#    7bbc641..e3d8ddf  main       -> origin/main
# Updating 7bbc641..e3d8ddf
# Fast-forward
#  hpc_hft/gpu_runner.ipynb | 255 ++++++++++++++++++++++++++++++++++++++++++++++-
#  hpc_hft/mat_mult.cu      |  28 +++---
#  2 files changed, 269 insertions(+), 14 deletions(-)

# %%
# !nvcc mat_mult.cu -o mat_mult
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
# !ls
# Out:
# cuda_includes  gpu_runner.ipynb  mat_mult
# executable     hello_cuda.cu	 mat_mult.cu

# %%
# !git push
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !./mat_mult
# Out:
# [1 ,1 ,10 ,
# 10 ,4 ,9 ,
# 10 ,1 ,1 ,]
# [5 ,8 ,9 ,
# 2 ,6 ,6 ,
# 4 ,7 ,5 ,]

# %%
# !git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 4), reused 5 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 1.12 KiB | 572.00 KiB/s, done.
# From https://github.com/Abhishek-Chintada/pieceOfShit
#    e3d8ddf..1ad113e  main       -> origin/main
# Updating e3d8ddf..1ad113e
# Fast-forward
#  hpc_hft/gpu_runner.ipynb | 109 ++++++++++++++++++++++++++++++++++++++++++++++-
#  hpc_hft/mat_mult.cu      |  10 +++--
#  2 files changed, 114 insertions(+), 5 deletions(-)

# %%
# !nvcc mat_mult.cu -o mat_mult
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# mat_mult.cu(89): error: a namespace name is not allowed
#       std::chrono:duration<double, std::milli> time = start - end;
#       ^
#
# mat_mult.cu(89): error: expected a ";"
#       std::chrono:duration<double, std::milli> time = start - end;
#                  ^
#
# 2 errors detected in the compilation of "mat_mult.cu".

# %%
# !git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 4), reused 5 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 774 bytes | 387.00 KiB/s, done.
# From https://github.com/Abhishek-Chintada/pieceOfShit
#    1ad113e..2d57bec  main       -> origin/main
# Updating 1ad113e..2d57bec
# Fast-forward
#  hpc_hft/gpu_runner.ipynb | 58 +++++++++++++++++++++++++++++++++++++++++++++++-
#  hpc_hft/mat_mult.cu      |  2 +-
#  2 files changed, 58 insertions(+), 2 deletions(-)

# %%
# !nvcc mat_mult.cu -o mat_mult
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# mat_mult.cu(89): error: identifier "start" is undefined
#       std::chrono::duration<double, std::milli> time = start - end;
#                                                        ^
#
# mat_mult.cu(89): error: identifier "end" is undefined
#       std::chrono::duration<double, std::milli> time = start - end;
#                                                                ^
#
# 2 errors detected in the compilation of "mat_mult.cu".

# %%
# !git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 4), reused 5 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 657 bytes | 328.00 KiB/s, done.
# From https://github.com/Abhishek-Chintada/pieceOfShit
#    2d57bec..fe4c286  main       -> origin/main
# Updating 2d57bec..fe4c286
# Fast-forward
#  hpc_hft/gpu_runner.ipynb | 58 +++++++++++++++++++++++++++++++++++++++++++++++-
#  hpc_hft/mat_mult.cu      |  2 +-
#  2 files changed, 58 insertions(+), 2 deletions(-)

# %%
# !nvcc mat_mult.cu -o mat_mult
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# mat_mult.cu: In function ‘int main()’:
# mat_mult.cu:90:8: warning: format ‘%lf’ expects argument of type ‘double’, but argument 2 has type ‘std::chrono::duration<double, std::ratio<1, 1000> >’ [-Wformat=]
#    90 |     printf("This the time taken for normal execution : %lf\n", time);
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~  ~~~~
#       |                                                            |
#       |                                                            std::chrono::duration<double, std::ratio<1, 1000> >

# %%
# !git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 4), reused 5 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 948 bytes | 158.00 KiB/s, done.
# From https://github.com/Abhishek-Chintada/pieceOfShit
#    fe4c286..aab17dc  main       -> origin/main
# Updating fe4c286..aab17dc
# Fast-forward
#  hpc_hft/gpu_runner.ipynb | 55 +++++++++++++++++++++++++++++++++++++++++++++++-
#  hpc_hft/mat_mult.cu      |  2 +-
#  2 files changed, 55 insertions(+), 2 deletions(-)

# %%
# !nvcc mat_mult.cu -o mat_mult
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
# !./mat_mult
# Out:
# [1 ,4 ,3 ,
# 6 ,6 ,2 ,
# 2 ,6 ,6 ,]
# [2 ,8 ,10 ,
# 10 ,4 ,5 ,
# 10 ,10 ,7 ,]
# [72 ,54 ,51 ,
# 92 ,92 ,104 ,
# 124 ,100 ,92 ,]
# This the time taken for normal execution : -0.005960

# %%
# !git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 4), reused 5 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 786 bytes | 393.00 KiB/s, done.
# From https://github.com/Abhishek-Chintada/pieceOfShit
#    aab17dc..9014464  main       -> origin/main
# Updating aab17dc..9014464
# Fast-forward
#  hpc_hft/gpu_runner.ipynb | 76 +++++++++++++++++++++++++++++++++++++++++++++++-
#  hpc_hft/mat_mult.cu      |  6 +++-
#  2 files changed, 80 insertions(+), 2 deletions(-)

# %%
# !nvcc mat_mult.cu -o mat_mult
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
# !./mat_mult
# Out:
# [9 ,7 ,1 ,
# 7 ,8 ,8 ,
# 5 ,5 ,3 ,]
# [7 ,9 ,8 ,
# 4 ,5 ,6 ,
# 3 ,2 ,6 ,]
# [94 ,118 ,120 ,
# 105 ,119 ,152 ,
# 64 ,76 ,88 ,]
# This the time taken for normal execution : 0.004575
# This is the time taken for the execution on GPU : 311.488876

# %%
# !git pull
# !nvcc mat_mult.cu -o mat_mult
# !./mat_mult
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 4), reused 5 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 730 bytes | 365.00 KiB/s, done.
# From https://github.com/Abhishek-Chintada/pieceOfShit
#    9014464..5732d89  main       -> origin/main
# Updating 9014464..5732d89
# Fast-forward
#  hpc_hft/gpu_runner.ipynb | 77 +++++++++++++++++++++++++++++++++++++++++++++++-
#  hpc_hft/mat_mult.cu      |  2 +-
#  2 files changed, 77 insertions(+), 2 deletions(-)
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# [7 ,9 ,2 ,1 ,10 ,7 ,10 ,1 ,2 ,3 ,1 ,1 ,8 ,9 ,9 ,1 ,1 ,8 ,6 ,5 ,8 ,1 ,9 ,6 ,9 ,4 ,3 ,3 ,6 ,3 ,4 ,5 ,
# 8 ,10 ,6 ,2 ,5 ,8 ,9 ,5 ,1 ,3 ,1 ,10 ,6 ,5 ,2 ,9 ,6 ,7 ,9 ,1 ,4 ,10 ,8 ,2 ,9 ,4 ,1 ,7 ,1 ,6 ,3 ,4 ,
# ...
